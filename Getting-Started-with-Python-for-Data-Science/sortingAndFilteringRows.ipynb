# %% [markdown]
# ##### 1: Row Indexes

# %%
import pandas as pd
vehicles = pd.read_csv('vehicles.csv')
vehicles.head()
# Out:
#       id                          model  year transmission   manufacturer  \
# 0  12988  amg e53 4matic+ (convertible)  2022         auto  mercedes-benz
# 1    689                  avalanche ffv  2007         auto      chevrolet
# 2    950                         impala  2010         auto      chevrolet
# 3    250                   yukon xl ffv  2004         auto            gmc
# 4  13089                    sf90 spyder  2022         auto        ferrari
#
#   vehicle_type                     fuel fuel_configuration  best_mpge
# 0  sedan/wagon          hybrid electric    hybrid electric       28.0
# 1       pickup            ethanol (e85)      flexible fuel       21.0
# 2  sedan/wagon            ethanol (e85)      flexible fuel       29.0
# 3          suv            ethanol (e85)      flexible fuel       18.0
# 4  sedan/wagon  plug-in hybrid electric    hybrid electric       19.0

# %%
vehicles.index
# Out:
# RangeIndex(start=0, stop=2520, step=1)

# %%
transmission_counts = vehicles['transmission'].value_counts()
transmission_counts
# Out:
# transmission
# auto                     2297
# continuously variable     107
# unknown                    48
# single                     35
# manual                     27
# transaxle                   3
# direct drive                3
# Name: count, dtype: int64

# %%
transmission_counts.index
# Out:
# Index(['auto', 'continuously variable', 'unknown', 'single', 'manual',
#        'transaxle', 'direct drive'],
#       dtype='object', name='transmission')

# %%
# Resetting to the standard RangeIndex
transmission_counts.reset_index()
# Out:
#             transmission  count
# 0                   auto   2297
# 1  continuously variable    107
# 2                unknown     48
# 3                 single     35
# 4                 manual     27
# 5              transaxle      3
# 6           direct drive      3

# %% [markdown]
# ##### 2: Sorting Rows

# %%
vehicles = vehicles.sort_values(by='year')
vehicles.head()
# Out:
#        id                     model  year transmission manufacturer  \
# 2082  649                taurus ffv  1991         auto         ford
# 1652  658  econoline-fleet demo ffv  1992      unknown         ford
# 1350  648                taurus ffv  1993         auto         ford
# 121   659  econoline-fleet demo ffv  1993      unknown         ford
# 480   632                taurus ffv  1994         auto         ford
#
#      vehicle_type           fuel fuel_configuration  best_mpge
# 2082  sedan/wagon       methanol      flexible fuel       26.0
# 1652          van       methanol      flexible fuel       17.0
# 1350  sedan/wagon       methanol      flexible fuel       26.0
# 121           van       methanol      flexible fuel       17.0
# 480   sedan/wagon  ethanol (e85)      flexible fuel       26.0

# %%
vehicles = vehicles.sort_values(by='best_mpge', ascending=False)
vehicles.head()
# Out:
#          id                            model  year transmission manufacturer  \
# 159   11844                   ioniq electric  2018         auto      hyundai
# 511   12752  model 3 standard range plus rwd  2021         auto        tesla
# 1507  11640                            ioniq  2017         auto      hyundai
# 2142  12061                   ioniq electric  2019         auto      hyundai
# 647   12370      model 3 standard range plus  2020         auto        tesla
#
#      vehicle_type      fuel fuel_configuration  best_mpge
# 159   sedan/wagon  electric          dedicated      150.0
# 511   sedan/wagon  electric          dedicated      150.0
# 1507  sedan/wagon  electric          dedicated      150.0
# 2142  sedan/wagon  electric          dedicated      150.0
# 647   sedan/wagon  electric          dedicated      148.0

# %%
vehicle_years = vehicles['year'].value_counts()
vehicle_years
# Out:
# year
# 2022    320
# 2021    263
# 2020    199
# 2019    194
# 2018    170
# 2017    142
# 2013    130
# 2015    123
# 2014    120
# 2011    109
# 2012     99
# 2016     89
# 2009     56
# 2010     56
# 2008     49
# 2007     46
# 2002     44
# 2003     42
# 2004     39
# 2005     37
# 1999     36
# 2006     36
# 2000     31
# 2001     28
# 1998     22
# 1997     16
# 1995      8
# 1996      8
# 2023      2
# 1993      2
# 1994      2
# 1991      1
# 1992      1
# Name: count, dtype: int64

# %%
vehicle_years.sort_index()
# Out:
# year
# 1991      1
# 1992      1
# 1993      2
# 1994      2
# 1995      8
# 1996      8
# 1997     16
# 1998     22
# 1999     36
# 2000     31
# 2001     28
# 2002     44
# 2003     42
# 2004     39
# 2005     37
# 2006     36
# 2007     46
# 2008     49
# 2009     56
# 2010     56
# 2011    109
# 2012     99
# 2013    130
# 2014    120
# 2015    123
# 2016     89
# 2017    142
# 2018    170
# 2019    194
# 2020    199
# 2021    263
# 2022    320
# 2023      2
# Name: count, dtype: int64

# %% [markdown]
# ##### 3: Selecting Specific Rows

# %%
vehicles = vehicles.sort_values(by='year', ascending=False)
vehicles.head()
# Out:
#          id                     model  year transmission manufacturer  \
# 718   13106                taycan gts  2023         auto      porsche
# 1940  13107             taycan gts st  2023         auto      porsche
# 1089  13017  model y (long range) awd  2022         auto        tesla
# 2448  13006                   ev6 rwd  2022         auto          kia
# 1901  13007     ev6 rwd (long range)   2022         auto          kia
#
#      vehicle_type      fuel fuel_configuration  best_mpge
# 718   sedan/wagon  electric          dedicated       83.0
# 1940  sedan/wagon  electric          dedicated       80.0
# 1089          suv  electric          dedicated      127.0
# 2448  sedan/wagon  electric          dedicated      136.0
# 1901  sedan/wagon  electric          dedicated      134.0

# %%
vehicles.loc[[1940, 718], ['manufacturer']]
# Out:
#      manufacturer
# 1940      porsche
# 718       porsche

# %%
vehicles.iloc[[0, 1], [6]]
# Out:
#           fuel
# 718   electric
# 1940  electric

# %% [markdown]
# ##### 4: Selecting Ranges of Rows<br>
# ###### NOTE:<br>
# ###### The slice's stopping index is incluced in loc, while not in iloc

# %%
vehicles = vehicles.sort_index()
vehicles.head()
# Out:
#       id                          model  year transmission   manufacturer  \
# 0  12988  amg e53 4matic+ (convertible)  2022         auto  mercedes-benz
# 1    689                  avalanche ffv  2007         auto      chevrolet
# 2    950                         impala  2010         auto      chevrolet
# 3    250                   yukon xl ffv  2004         auto            gmc
# 4  13089                    sf90 spyder  2022         auto        ferrari
#
#   vehicle_type                     fuel fuel_configuration  best_mpge
# 0  sedan/wagon          hybrid electric    hybrid electric       28.0
# 1       pickup            ethanol (e85)      flexible fuel       21.0
# 2  sedan/wagon            ethanol (e85)      flexible fuel       29.0
# 3          suv            ethanol (e85)      flexible fuel       18.0
# 4  sedan/wagon  plug-in hybrid electric    hybrid electric       19.0

# %%
vehicles.iloc[:4, :5]
# Out:
#       id                          model  year transmission   manufacturer
# 0  12988  amg e53 4matic+ (convertible)  2022         auto  mercedes-benz
# 1    689                  avalanche ffv  2007         auto      chevrolet
# 2    950                         impala  2010         auto      chevrolet
# 3    250                   yukon xl ffv  2004         auto            gmc

# %%
vehicles.loc[1:2, 'vehicle_type':'fuel_configuration']
# Out:
#   vehicle_type           fuel fuel_configuration
# 1       pickup  ethanol (e85)      flexible fuel
# 2  sedan/wagon  ethanol (e85)      flexible fuel

# %%
vehicles.loc[:20, 'year':]
# Out:
#     year transmission   manufacturer vehicle_type  \
# 0   2022         auto  mercedes-benz  sedan/wagon
# 1   2007         auto      chevrolet       pickup
# 2   2010         auto      chevrolet  sedan/wagon
# 3   2004         auto            gmc          suv
# 4   2022         auto        ferrari  sedan/wagon
# 5   2020         auto      chevrolet       pickup
# 6   2022         auto  mercedes-benz          suv
# 7   2022         auto         toyota  sedan/wagon
# 8   2013         auto            gmc       pickup
# 9   2022         auto            bmw          suv
# 10  2013      unknown          smart  sedan/wagon
# 11  2013         auto           jeep          suv
# 12  1998         auto           ford          van
# 13  2012         auto      chevrolet  sedan/wagon
# 14  2021         auto           audi  sedan/wagon
# 15  2014         auto         jaguar  sedan/wagon
# 16  2018         auto            kia  sedan/wagon
# 17  2019         auto       chrysler  sedan/wagon
# 18  2007         auto            gmc       pickup
# 19  2019         auto      chevrolet  sedan/wagon
# 20  2011         auto           ford          van
#
#                             fuel fuel_configuration  best_mpge
# 0                hybrid electric    hybrid electric       28.0
# 1                  ethanol (e85)      flexible fuel       21.0
# 2                  ethanol (e85)      flexible fuel       29.0
# 3                  ethanol (e85)      flexible fuel       18.0
# 4        plug-in hybrid electric    hybrid electric       19.0
# 5                  ethanol (e85)      flexible fuel       18.0
# 6                hybrid electric    hybrid electric       21.0
# 7                hybrid electric    hybrid electric       43.0
# 8                  ethanol (e85)      flexible fuel       18.0
# 9                hybrid electric    hybrid electric       25.0
# 10                      electric          dedicated      112.0
# 11                 ethanol (e85)      flexible fuel       23.0
# 12  cng - compressed natural gas     dual/bi-fueled       17.0
# 13                 ethanol (e85)      flexible fuel       30.0
# 14               hybrid electric    hybrid electric       31.0
# 15                 ethanol (e85)      flexible fuel       27.0
# 16       plug-in hybrid electric    hybrid electric      103.0
# 17                 ethanol (e85)      flexible fuel       27.0
# 18               hybrid electric    hybrid electric       21.0
# 19               biodiesel (b20)          dedicated       48.0
# 20                 ethanol (e85)      flexible fuel       16.0

# %% [markdown]
# ##### 5: Boolean Masks

# %%
gt25 = vehicles['best_mpge'] >= 25
gt25.head()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# Name: best_mpge, dtype: bool

# %%
is_sedanwagon = vehicles['vehicle_type'] == 'sedan/wagon'
is_sedanwagon.head()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: vehicle_type, dtype: bool

# %% [markdown]
# ##### 6: Filtering Rows with Booleans

# %%
gt40 = vehicles['best_mpge'] > 40
vehicles[gt40].head()
# Out:
#        id                  model  year transmission manufacturer vehicle_type  \
# 7   12875         avalon hybrid   2022         auto       toyota  sedan/wagon
# 10  10539                 fortwo  2013      unknown        smart  sedan/wagon
# 16  11948  optima plug-in hybrid  2018         auto          kia  sedan/wagon
# 19  12035                  cruze  2019         auto    chevrolet  sedan/wagon
# 21  11909      fusion hybrid fwd  2018         auto         ford  sedan/wagon
#
#                        fuel fuel_configuration  best_mpge
# 7           hybrid electric    hybrid electric       43.0
# 10                 electric          dedicated      112.0
# 16  plug-in hybrid electric    hybrid electric      103.0
# 19          biodiesel (b20)          dedicated       48.0
# 21          hybrid electric    hybrid electric       43.0

# %%
vehicles[vehicles['transmission'] == 'auto'].head()
# Out:
#       id                          model  year transmission   manufacturer  \
# 0  12988  amg e53 4matic+ (convertible)  2022         auto  mercedes-benz
# 1    689                  avalanche ffv  2007         auto      chevrolet
# 2    950                         impala  2010         auto      chevrolet
# 3    250                   yukon xl ffv  2004         auto            gmc
# 4  13089                    sf90 spyder  2022         auto        ferrari
#
#   vehicle_type                     fuel fuel_configuration  best_mpge
# 0  sedan/wagon          hybrid electric    hybrid electric       28.0
# 1       pickup            ethanol (e85)      flexible fuel       21.0
# 2  sedan/wagon            ethanol (e85)      flexible fuel       29.0
# 3          suv            ethanol (e85)      flexible fuel       18.0
# 4  sedan/wagon  plug-in hybrid electric    hybrid electric       19.0

# %% [markdown]
# ##### 7: Combining Booleans with AND

# %%
vehicle_year = vehicles['year'] > 2016
vehicle_fuel = vehicles['fuel'] == 'electric'
combined = vehicles[vehicle_year & vehicle_fuel]
combined.sort_values(by='year', ascending=False).head()
# Out:
#          id                         model  year transmission     manufacturer  \
# 718   13106                    taycan gts  2023         auto          porsche
# 1940  13107                 taycan gts st  2023         auto          porsche
# 72    12897  air dream r awd w/21" wheels  2022         auto  lucid usa, inc.
# 194   13013                   model 3 rwd  2022         auto            tesla
# 264   12969  taycan turbo s cross turismo  2022         auto          porsche
#
#      vehicle_type      fuel fuel_configuration  best_mpge
# 718   sedan/wagon  electric          dedicated       83.0
# 1940  sedan/wagon  electric          dedicated       80.0
# 72    sedan/wagon  electric          dedicated      117.0
# 194   sedan/wagon  electric          dedicated      138.0
# 264   sedan/wagon  electric          dedicated       74.0

# %%
vehicles[(vehicles['fuel'] == 'biodiesel (b20)') & (vehicles['best_mpge'] > 40)].sort_values(by='year', ascending=False).head()
# Out:
#          id            model  year transmission manufacturer vehicle_type  \
# 19    12035            cruze  2019         auto    chevrolet  sedan/wagon
# 499   12206               xf  2019         auto       jaguar  sedan/wagon
# 564   12036  cruze hatchback  2019         auto    chevrolet  sedan/wagon
# 2286  12204               xe  2019         auto       jaguar  sedan/wagon
# 501   11824               xf  2018         auto       jaguar  sedan/wagon
#
#                  fuel fuel_configuration  best_mpge
# 19    biodiesel (b20)          dedicated       48.0
# 499   biodiesel (b20)          dedicated       42.0
# 564   biodiesel (b20)          dedicated       45.0
# 2286  biodiesel (b20)          dedicated       42.0
# 501   biodiesel (b20)          dedicated       42.0

# %% [markdown]
# ##### 8: Combining Booleans with OR

# %%
is_ethanol = vehicles['fuel'] == 'ethanol (e85)'
is_methanol = vehicles['fuel'] == 'methanol'
combined = is_ethanol | is_methanol
vehicles[combined].sort_values(by='year', ascending=False).head()
# Out:
#          id                              model  year transmission  \
# 2429  12973                      f-150 4wd ffv  2022         auto
# 1394  12976                   explorer awd ffv  2022         auto
# 2512  12998     sierra 4wd - mud terrain tires  2022         auto
# 2348  12927                         sierra 4wd  2022         auto
# 1283  12997  silverado 4wd - mud terrain tires  2022         auto
#
#      manufacturer vehicle_type           fuel fuel_configuration  best_mpge
# 2429         ford       pickup  ethanol (e85)      flexible fuel       22.0
# 1394         ford          suv  ethanol (e85)      flexible fuel       24.0
# 2512          gmc       pickup  ethanol (e85)      flexible fuel       16.0
# 2348          gmc       pickup  ethanol (e85)      flexible fuel       18.0
# 1283    chevrolet       pickup  ethanol (e85)      flexible fuel       16.0

# %%
is_electric = vehicles['fuel'] == 'electric'
gt40 = vehicles['best_mpge'] > 40
electric_or_above_average = vehicles[is_electric | gt40]
electric_or_above_average.head()
# Out:
#        id                  model  year transmission manufacturer vehicle_type  \
# 7   12875         avalon hybrid   2022         auto       toyota  sedan/wagon
# 10  10539                 fortwo  2013      unknown        smart  sedan/wagon
# 16  11948  optima plug-in hybrid  2018         auto          kia  sedan/wagon
# 19  12035                  cruze  2019         auto    chevrolet  sedan/wagon
# 21  11909      fusion hybrid fwd  2018         auto         ford  sedan/wagon
#
#                        fuel fuel_configuration  best_mpge
# 7           hybrid electric    hybrid electric       43.0
# 10                 electric          dedicated      112.0
# 16  plug-in hybrid electric    hybrid electric      103.0
# 19          biodiesel (b20)          dedicated       48.0
# 21          hybrid electric    hybrid electric       43.0

# %% [markdown]
# ##### 9: Inverting Booleans with NOT

# %%
is_ford = vehicles['manufacturer'] == 'ford'
is_truck = vehicles['vehicle_type'] == 'pickup'
is_ford_truck = is_ford & is_truck
not_ford_truck = ~is_ford_truck
vehicles[not_ford_truck].head()
# Out:
#       id                          model  year transmission   manufacturer  \
# 0  12988  amg e53 4matic+ (convertible)  2022         auto  mercedes-benz
# 1    689                  avalanche ffv  2007         auto      chevrolet
# 2    950                         impala  2010         auto      chevrolet
# 3    250                   yukon xl ffv  2004         auto            gmc
# 4  13089                    sf90 spyder  2022         auto        ferrari
#
#   vehicle_type                     fuel fuel_configuration  best_mpge
# 0  sedan/wagon          hybrid electric    hybrid electric       28.0
# 1       pickup            ethanol (e85)      flexible fuel       21.0
# 2  sedan/wagon            ethanol (e85)      flexible fuel       29.0
# 3          suv            ethanol (e85)      flexible fuel       18.0
# 4  sedan/wagon  plug-in hybrid electric    hybrid electric       19.0

# %%
is_chevrolet = vehicles['manufacturer'] == 'chevrolet'
is_gmc = vehicles['manufacturer'] == 'gmc'
not_chevrolet_gmc = vehicles[~(is_chevrolet | is_gmc)]
not_chevrolet_gmc.head()
# Out:
#       id                          model  year transmission   manufacturer  \
# 0  12988  amg e53 4matic+ (convertible)  2022         auto  mercedes-benz
# 4  13089                    sf90 spyder  2022         auto        ferrari
# 6  12989     amg gle 53 4matic+ (coupe)  2022         auto  mercedes-benz
# 7  12875                 avalon hybrid   2022         auto         toyota
# 9  12864                   x6 xdrive40i  2022         auto            bmw
#
#   vehicle_type                     fuel fuel_configuration  best_mpge
# 0  sedan/wagon          hybrid electric    hybrid electric       28.0
# 4  sedan/wagon  plug-in hybrid electric    hybrid electric       19.0
# 6          suv          hybrid electric    hybrid electric       21.0
# 7  sedan/wagon          hybrid electric    hybrid electric       43.0
# 9          suv          hybrid electric    hybrid electric       25.0
